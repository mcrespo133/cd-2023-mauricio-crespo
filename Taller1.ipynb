# %% [markdown]
# <a href="https://colab.research.google.com/github/mcrespo133/cd-2023-mauricio-crespo/blob/main/Taller1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [10,11,12,13,14,15,16]
y = [146,154,163,174,182,186,191]

slope, intercept, r, p, std_err = stats.linregress(x,y)

def funcion(x):
  return slope * x + intercept

modelo = list(map(funcion, x))

plt.scatter(x, y)
plt.plot(x, modelo)
plt.show()
